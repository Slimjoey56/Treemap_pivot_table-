# %%
pip install pandas matplotlib
# Out:
# Requirement already satisfied: pandas in c:\users\subway\jupyterproject2\.venv\lib\site-packages (3.0.2)
# Requirement already satisfied: matplotlib in c:\users\subway\jupyterproject2\.venv\lib\site-packages (3.10.8)
# Requirement already satisfied: numpy>=2.3.3 in c:\users\subway\jupyterproject2\.venv\lib\site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\subway\jupyterproject2\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\subway\jupyterproject2\.venv\lib\site-packages (from pandas) (2026.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\subway\jupyterproject2\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\subway\jupyterproject2\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\subway\jupyterproject2\.venv\lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\subway\jupyterproject2\.venv\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\subway\jupyterproject2\.venv\lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\subway\jupyterproject2\.venv\lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\subway\jupyterproject2\.venv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in c:\users\subway\jupyterproject2\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Define the parameters
num_quarters = 4
num_categories = 4
num_subcategories = 3
num_samples = num_quarters * num_categories * num_subcategories*50

# Generate sample sales data
np.random.seed(40)

# Creating sample data
dates = np.repeat(['Q1','Q2','Q3','Q4'], 50*num_categories * num_subcategories)
categories = np.tile(np.random.choice(['Laptops', 'Desktops', 'Peripherals', 'Software'], size=num_quarters*50), num_categories * num_subcategories)
subcategories = np.tile(np.random.choice(['Accessories', 'Components', 'Software Suites'], size=num_quarters*50), num_categories * num_subcategories)
sales_values = np.random.randint(1000, 5000, size=num_samples)

# Create DataFrame
df = pd.DataFrame({
    'Date': dates,
    'Category': categories,
    'Subcategory': subcategories,
    'Sales': sales_values
})

# %%
# Create pivot table
pivot_table = df.pivot_table(index='Date', columns=['Category','Subcategory'], values='Sales', aggfunc=np.sum)

# %%
# Plotting a pivot chart
pivot_table.plot(kind='bar', figsize=(14, 8))
plt.title('Sales Summary of IT Products by Category and Subcategory')
plt.xlabel('Quarters')
plt.ylabel('Total Sales')
plt.grid(False)
plt.legend(title=('Category', 'Subcategory'), bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
